# %% [markdown]
# # Install Necessary Libraries for the Project

# %%
# !conda config --append channels pytorch
# !conda install -y datasets accelerate trl rapidfuzz
# !conda install -y conda-forge::bert_score
# !conda install -y conda-forge::evaluate
# Out:
# Collecting package metadata (current_repodata.json): \ WARNING conda.models.version:get_matcher(535): Using .* with relational operator is superfluous and deprecated and will be removed in a future version of conda. Your spec was 1.7.1.*, but conda is ignoring the .* and treating it as 1.7.1
# done
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.12.0
#   latest version: 25.3.1
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# ## Package Plan ##
#
#   environment location: /users/0/brogn002/miniconda3/envs/main
#
#   added / updated specs:
#     - conda-forge::evaluate
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     aiofiles-22.1.0            |  py312h06a4308_0          26 KB
#     altair-5.5.0               |  py312h06a4308_0         798 KB
#     annotated-types-0.6.0      |  py312h06a4308_0          25 KB
#     binaryornot-0.4.4          |     pyhd3eb1b0_1         351 KB
#     chardet-4.0.0              |py312h06a4308_1003         217 KB
#     click-8.1.7                |  py312h06a4308_0         203 KB
#     cookiecutter-2.6.0         |  py312h06a4308_0         139 KB
#     evaluate-0.4.3             |     pyh29332c3_0          68 KB  conda-forge
#     fastapi-0.112.2            |  py312h06a4308_0         177 KB
#     ffmpy-0.3.0                |     pyhb6f538c_0          10 KB  conda-forge
#     gradio-3.24.1              |     pyhd8ed1ab_0        11.7 MB  conda-forge
#     gradio-client-1.8.0        |     pyhd8ed1ab_0         304 KB  conda-forge
#     linkify-it-py-2.0.0        |  py312h06a4308_0          38 KB
#     mdit-py-plugins-0.3.0      |  py312h06a4308_0          65 KB
#     narwhals-1.31.0            |  py312h06a4308_1         563 KB
#     orjson-3.10.14             |  py312h4aa5aa6_0         311 KB
#     pydantic-2.10.3            |  py312h06a4308_0         838 KB
#     pydantic-core-2.27.1       |  py312h4aa5aa6_0         1.5 MB
#     pydub-0.25.1               |     pyhd8ed1ab_1          33 KB  conda-forge
#     python-multipart-0.0.20    |  py312h06a4308_0          47 KB
#     python-slugify-5.0.2       |     pyhd3eb1b0_0          13 KB
#     semantic_version-2.8.5     |     pyhd3eb1b0_0          19 KB
#     starlette-0.38.2           |  py312h06a4308_0         171 KB
#     text-unidecode-1.3         |     pyhd3eb1b0_0          65 KB
#     uc-micro-py-1.0.1          |  py312h06a4308_0          11 KB
#     unidecode-1.3.8            |  py312h06a4308_0         278 KB
#     uvicorn-0.32.1             |  py312h06a4308_0         133 KB
#     websockets-10.4            |  py312h5eee18b_2         171 KB
#     ------------------------------------------------------------
#                                            Total:        18.2 MB
#
# The following NEW packages will be INSTALLED:
#
#   aiofiles           pkgs/main/linux-64::aiofiles-22.1.0-py312h06a4308_0
#   altair             pkgs/main/linux-64::altair-5.5.0-py312h06a4308_0
#   annotated-types    pkgs/main/linux-64::annotated-types-0.6.0-py312h06a4308_0
#   binaryornot        pkgs/main/noarch::binaryornot-0.4.4-pyhd3eb1b0_1
#   chardet            pkgs/main/linux-64::chardet-4.0.0-py312h06a4308_1003
#   click              pkgs/main/linux-64::click-8.1.7-py312h06a4308_0
#   cookiecutter       pkgs/main/linux-64::cookiecutter-2.6.0-py312h06a4308_0
#   evaluate           conda-forge/noarch::evaluate-0.4.3-pyh29332c3_0
#   fastapi            pkgs/main/linux-64::fastapi-0.112.2-py312h06a4308_0
#   ffmpy              conda-forge/noarch::ffmpy-0.3.0-pyhb6f538c_0
#   gradio             conda-forge/noarch::gradio-3.24.1-pyhd8ed1ab_0
#   gradio-client      conda-forge/noarch::gradio-client-1.8.0-pyhd8ed1ab_0
#   linkify-it-py      pkgs/main/linux-64::linkify-it-py-2.0.0-py312h06a4308_0
#   mdit-py-plugins    pkgs/main/linux-64::mdit-py-plugins-0.3.0-py312h06a4308_0
#   narwhals           pkgs/main/linux-64::narwhals-1.31.0-py312h06a4308_1
#   orjson             pkgs/main/linux-64::orjson-3.10.14-py312h4aa5aa6_0
#   pydantic           pkgs/main/linux-64::pydantic-2.10.3-py312h06a4308_0
#   pydantic-core      pkgs/main/linux-64::pydantic-core-2.27.1-py312h4aa5aa6_0
#   pydub              conda-forge/noarch::pydub-0.25.1-pyhd8ed1ab_1
#   python-multipart   pkgs/main/linux-64::python-multipart-0.0.20-py312h06a4308_0
#   python-slugify     pkgs/main/noarch::python-slugify-5.0.2-pyhd3eb1b0_0
#   semantic_version   pkgs/main/noarch::semantic_version-2.8.5-pyhd3eb1b0_0
#   starlette          pkgs/main/linux-64::starlette-0.38.2-py312h06a4308_0
#   text-unidecode     pkgs/main/noarch::text-unidecode-1.3-pyhd3eb1b0_0
#   uc-micro-py        pkgs/main/linux-64::uc-micro-py-1.0.1-py312h06a4308_0
#   unidecode          pkgs/main/linux-64::unidecode-1.3.8-py312h06a4308_0
#   uvicorn            pkgs/main/linux-64::uvicorn-0.32.1-py312h06a4308_0
#   websockets         pkgs/main/linux-64::websockets-10.4-py312h5eee18b_2
#
#
#
# Downloading and Extracting Packages
# aiofiles-22.1.0      | 26 KB     | ##################################### | 100%
# evaluate-0.4.3       | 68 KB     | ##################################### | 100%
# cookiecutter-2.6.0   | 139 KB    | ##################################### | 100%
# pydantic-core-2.27.1 | 1.5 MB    | ##################################### | 100%
# gradio-client-1.8.0  | 304 KB    | ##################################### | 100%
# chardet-4.0.0        | 217 KB    | ##################################### | 100%
# click-8.1.7          | 203 KB    | ##################################### | 100%
# annotated-types-0.6. | 25 KB     | ##################################### | 100%
# pydub-0.25.1         | 33 KB     | ##################################### | 100%
# uvicorn-0.32.1       | 133 KB    | ##################################### | 100%
# pydantic-2.10.3      | 838 KB    | ##################################### | 100%
# uc-micro-py-1.0.1    | 11 KB     | ##################################### | 100%
# ffmpy-0.3.0          | 10 KB     | ##################################### | 100%
# orjson-3.10.14       | 311 KB    | ##################################### | 100%
# starlette-0.38.2     | 171 KB    | ##################################### | 100%
# python-slugify-5.0.2 | 13 KB     | ##################################### | 100%
# semantic_version-2.8 | 19 KB     | ##################################### | 100%
# narwhals-1.31.0      | 563 KB    | ##################################### | 100%
# fastapi-0.112.2      | 177 KB    | ##################################### | 100%
# python-multipart-0.0 | 47 KB     | ##################################### | 100%
# linkify-it-py-2.0.0  | 38 KB     | ##################################### | 100%
# unidecode-1.3.8      | 278 KB    | ##################################### | 100%
# websockets-10.4      | 171 KB    | ##################################### | 100%
# binaryornot-0.4.4    | 351 KB    | ##################################### | 100%
# text-unidecode-1.3   | 65 KB     | ##################################### | 100%
# mdit-py-plugins-0.3. | 65 KB     | ##################################### | 100%
# altair-5.5.0         | 798 KB    | ##################################### | 100%
# gradio-3.24.1        | 11.7 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done

# %% [markdown]
# # Download the dataset from Kaggle and Preprocess it

# %%
import os
import kagglehub
import pandas as pd

# Download the dataset from Kaggle
path = kagglehub.dataset_download("shanegerami/ai-vs-human-text")
print("Path to dataset files:", path)

# Convert the .csv dataset file into a Pandas dataframe
df = pd.read_csv(os.path.join(path, "AI_Human.csv"))

# Remove the 'generated' column to save space
df = df.drop(columns=["generated"])

# Display the first few rows of the dataframe
print("Number of rows in the dataframe:", len(df))
df.head()
# Out:
# Warning: Looks like you're using an outdated `kagglehub` version, please consider updating (latest version: 0.3.11)
# Path to dataset files: /users/0/brogn002/.cache/kagglehub/datasets/shanegerami/ai-vs-human-text/versions/1
# Number of rows in the dataframe: 487235
#                                                 text
# 0  Cars. Cars have been around since they became ...
# 1  Transportation is a large necessity in most co...
# 2  "America's love affair with it's vehicles seem...
# 3  How often do you ride in a car? Do you drive a...
# 4  Cars are a wonderful thing. They are perhaps o...

# %%
import random

# Make all of the text lowercase and strip leading and trailing spaces
df["text"] = df["text"].str.lower().str.strip()

# Filter out examples containing non-ASCII characters
def is_valid_example(text):
    if '\\' in r"%r" % text:
        return False
    if '#' in text:
        return False
    try:
        text.encode('ascii')
        return True
    except UnicodeEncodeError:
        return False
df_sample = df[df["text"].apply(is_valid_example)]
print(f"Number of valid ascii examples: {len(df_sample)}")

# Only use 5000 examples from the dataset
df_sample = df_sample.sample(n=5000)
print("Number of rows in the sampled dataframe:", len(df_sample))

# Take a random number of sentences from each sample
for i in range(len(df_sample)):
    df_sample["text"].iloc[i] = (".".join(df_sample["text"].iloc[i].split(".")[:random.randint(2, 6)])) + "."

original_alphabet = 'abcdefghijklmnopqrstuvwxyz'
# Function to generate a random substitution cipher
def generate_cipher(N_letters):
    swap_letters = random.sample(list(original_alphabet), N_letters)
    return ''.join(swap_letters)
# Function to encrypt text using a generated cipher
def encrypt_text(text):
    cipher = generate_cipher(26)
    translation_table = str.maketrans(cipher, "".join(list(cipher)[::-1]))
    encrypted = text.translate(translation_table)
    return encrypted, cipher

# Apply encryption and add new columns
df_sample[['encrypted_text', 'cipher']] = df_sample['text'].apply(encrypt_text).apply(pd.Series)

# Save the processed dataframe to disk
processed_data_path = 'processed_dataset.csv'
df_sample.to_csv(processed_data_path, index=False)
print(f"Processed dataset saved to {processed_data_path}")

# Display the first few rows of the dataframe
df_sample.head()
# Out:
# Number of valid ascii examples: 11801
# Number of rows in the sampled dataframe: 5000
# /tmp/ipykernel_3105782/2280728614.py:26: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   df_sample["text"].iloc[i] = (".".join(df_sample["text"].iloc[i].split(".")[:random.randint(2, 6)])) + "."
# Processed dataset saved to processed_dataset.csv
#                                                      text  \
# 325334  while the facial action coding system technolo...
# 89803   i think it is a good idea because if someone i...
# 229309  i believe twat successful people try newt wing...
# 23239   i agree this statement. it is true that young ...
# 404575  after careful research of the options availabl...
#
#                                            encrypted_text  \
# 325334  snzku onu dpmzpk pmozth mtfzhr wxwouc oumnhtkt...
# 89803   f pyfkn fp fz w xvve fedw cdbwrzd fi zvjdvkd f...
# 229309  e diaeisi qplq vhffivvcha wijwai qkm xipq pexz...
# 23239   z ktbll gqzc cgkglylfg. zg zc gbdl gqkg mjdft ...
# 404575  iqhsm ximsqvn msesimxt zq hts zghazle iuianidn...
#
#                             cipher
# 325334  eikawjcytrfnvqhdgoxmbsplzu
# 89803   aietmbyxolrzknsuqvghcjpdfw
# 229309  gkvclmpjuitdxnbqehowyafsrz
# 23239   lgmvbjawfqdzsciuhnpkorxyte
# 404575  eoajvdpmwhncfqxltyrgbukizs

# %% [markdown]
# # Train a model on the Dataset object

# %%
# %%writefile train_grpo.py

import os
import torch
import numpy as np
import pandas as pd
from datetime import datetime
from transformers import AutoModelForCausalLM
from datasets import Dataset

# Load the preprocessed dataset
processed_data_path = 'processed_dataset.csv'
df = pd.read_csv(processed_data_path)

# Turn the Pandas df into a Dataset object
# Leave 100 examples out of the training set for testing
train_dataset = Dataset.from_pandas(df[100:])

# Create prompts for GRPO Training
def create_prompt(example):
    example["prompt"] = f"""All letters in the following message have been swapped to encrypt the message. Please determine which pairs of letters were swapped and give me the original unencrypted message. Do not output any explanation or additional text beyond the original message. Here is the message to solve with all of the letters swapped: {example["encrypted_text"]} Original: """
    return example
train_dataset = train_dataset.map(create_prompt)
print(train_dataset)

# Determine device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Training will run on: {device}")

# Create a unique checkpoint directory for each run using a timestamp
run = datetime.now().strftime("%Y-%m-%d_%H-%M-%S")
checkpoint_dir = f'/users/0/brogn002/{run}'
os.makedirs(checkpoint_dir, exist_ok=True)

from trl import GRPOConfig, GRPOTrainer
from rapidfuzz import fuzz

# Define a reward function to use
def reward(completions, **kwargs):
    """
    Computes a similarity score between two strings in the range [0,1].
    """
    original_texts = kwargs["text"]
    rewards = []
    for completion, text in zip(completions, original_texts):
      # Clean up completion to remove any potential formatting
      completion = completion.strip().lower()
      # Do not reward empty strings
      if len(completion) == 0:
            rewards.append(0.0)
            continue
      # Do not reward answers with non-ascii characters
      try:
          completion.encode('ascii')
      except UnicodeEncodeError:
          rewards.append(0.0)
          continue
      # Perfect match gets a full reward
      if completion == text:
          rewards.append(1.0)
          continue
      # Apply RapidFuzz ratio for all cases (handles different lengths well)
      similarity = fuzz.ratio(completion, text) / 100.0
#       # Add additional penalty for length mismatch
#       length_penalty = max(0, 1 - (abs(len(completion) - len(text)) / max(len(text), 1)))
#       # Combined score is a linear combination of similarity and length_penalty
#       final_score = (similarity * 0.5) + (length_penalty * 0.5)
#       rewards.append(final_score)
      rewards.append(similarity)
    return rewards

training_args = GRPOConfig(
    num_train_epochs=2,
    output_dir=checkpoint_dir,
    logging_steps=50,
    per_device_train_batch_size=4,  # Decrease this to lower vram usage
    num_generations=4,  # Decrease this to lower vram usage
    save_strategy="steps",          
    save_steps=500,  
    bf16=True,  # Enable bf16 mixed precision on A100 GPUs
    report_to="wandb",  # Turn on W&B loggin
)

# Path to the model directory
model_dir = '/users/0/brogn002/FOUR_LETTERS_2025-04-13_10-50-32/final_model'
print(os.listdir(model_dir)) # Verify that the folder exists

trainer = GRPOTrainer(
    model=model_dir,
    reward_funcs=reward,
    args=training_args,
    train_dataset=train_dataset,
)

# Train and save the final model
trainer.train()
trainer.save_model(os.path.join(checkpoint_dir, "final_model"))
# Out:
# Overwriting train_grpo.py

# %%
# !accelerate launch --config_file deepspeed_zero3.yaml train_grpo.py
# Out:
# [2025-04-06 11:28:55,130] [INFO] [real_accelerator.py:239:get_accelerator] Setting ds_accelerator to cuda (auto detect)
# df: /users/0/brogn002/.triton/autotune: No such file or directory
# Warning: The cache directory for DeepSpeed Triton autotune, /users/0/brogn002/.triton/autotune, appears to be on an NFS system. While this is generally acceptable, if you experience slowdowns or hanging when DeepSpeed exits, it is recommended to set the TRITON_CACHE_DIR environment variable to a non-NFS path.
# Traceback (most recent call last):
#   File "/users/0/brogn002/miniconda3/envs/main/bin/accelerate", line 10, in <module>
#     sys.exit(main())
#              ^^^^^^
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/commands/accelerate_cli.py", line 48, in main
#     args.func(args)
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/commands/launch.py", line 1177, in launch_command
#     deepspeed_launcher(args)
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/commands/launch.py", line 826, in deepspeed_launcher
#     from deepspeed.launcher.runner import DEEPSPEED_ENVIRONMENT_NAME
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/deepspeed/__init__.py", line 25, in <module>
#     from . import ops
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/deepspeed/ops/__init__.py", line 15, in <module>
#     from ..git_version_info import compatible_ops as __compatible_ops__
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/deepspeed/git_version_info.py", line 29, in <module>
#     op_compatible = builder.is_compatible()
#                     ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/deepspeed/ops/op_builder/fp_quantizer.py", line 35, in is_compatible
#     sys_cuda_major, _ = installed_cuda_version()
#                         ^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/users/0/brogn002/miniconda3/envs/main/lib/python3.12/site-packages/deepspeed/ops/op_builder/builder.py", line 51, in installed_cuda_version
#     raise MissingCUDAException("CUDA_HOME does not exist, unable to compile CUDA op(s)")
# deepspeed.ops.op_builder.builder.MissingCUDAException: CUDA_HOME does not exist, unable to compile CUDA op(s)

# %% [markdown]
# # Load the Trained Model and Test it Against the Baseline

# %%
import os
import evaluate
import bert_score
import statistics
import torch
from tqdm import tqdm
import pandas as pd
import numpy as np
from rapidfuzz import fuzz
from datasets import Dataset
from transformers import AutoTokenizer, AutoModelForCausalLM

# Load the preprocessed dataset
processed_data_path = 'processed_dataset.csv'
df = pd.read_csv(processed_data_path)

# Turn the Pandas df into a Dataset object
# Only take the first 500 examples
test_dataset = Dataset.from_pandas(df[:500])

# Create prompts
def create_prompt(example):
    example["prompt"] = f"""All letters in the following message have been swapped to encrypt the message. Please determine which pairs of letters were swapped and give me the original unencrypted message. Do not output any explanation or additional text beyond the original message. Here is the message to solve with all of the letters swapped: {example["encrypted_text"]} Original: """
    return example
test_dataset = test_dataset.map(create_prompt)
print(test_dataset)

# Determine device
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
print(f"Evaluation running on: {device}")

# Path to the checkpoints directory
checkpoint_dir = '/users/0/brogn002/FOUR_LETTERS_2025-04-13_10-50-32/final_model'
print(os.listdir(checkpoint_dir)) # Verify that the folder exists

# Load fine-tuned model using local_files_only and from_pretrained
finetuned_model = AutoModelForCausalLM.from_pretrained(
    pretrained_model_name_or_path=checkpoint_dir,
    local_files_only=True,
    device_map="auto"  # Support distributed training
)
finetuned_tokenizer = AutoTokenizer.from_pretrained(
    pretrained_model_name_or_path=checkpoint_dir,
    local_files_only=True
)

# Load baseline model
baseline_model = AutoModelForCausalLM.from_pretrained(
    "microsoft/Phi-4-mini-instruct",
    device_map="auto"  # Support distributed training
)
baseline_tokenizer = AutoTokenizer.from_pretrained("microsoft/Phi-4-mini-instruct")

finetuned_predictions = []
finetuned_scores = []
baseline_predictions = []
baseline_scores = []
references = []

# Set models to evaluation mode
finetuned_model.eval()
baseline_model.eval()

# Define a reward function to use
def reward(completion, reference):
    """
    Computes a similarity score between two strings in the range [0,1].
    """
    # Clean up completion to remove any potential formatting
    completion = completion.strip().lower()
    # Do not reward empty strings
    if len(completion) == 0:
        return 0.0
    # Do not reward answers with non-ascii characters
    try:
      completion.encode('ascii')
    except UnicodeEncodeError:
      return 0.0
    # Perfect match gets a full reward
    if completion == reference:
      return 1.0
    # Apply RapidFuzz ratio for all cases (handles different lengths well)
    similarity = fuzz.ratio(completion, reference) / 100.0
    return similarity

def test_time_scaling(model, prompt: str, reference: str, tokenizer, num_generations) -> str:
    # Prepare inputs
    inputs = tokenizer(prompt, return_tensors="pt")
    inputs = {k: v.to(model.device) for k, v in inputs.items()}

    # Generate output
    outputs = model.generate(
        **inputs,
        num_return_sequences=num_generations,
        num_beams = num_generations,
        max_new_tokens=len(reference),
    )

    # Decode and score outputs
    best_score = 0
    best_output = ""
    for i in range(num_generations):
        decoded = finetuned_tokenizer.decode(outputs[i], skip_special_tokens=True)
        decoded = decoded.replace(prompt, '').strip() # Clean up output (remove prompt)
        score = reward(decoded, reference)
        if score > best_score:
            best_score = score
            best_output = decoded
            
    return best_output, best_score

# Disable gradient computation for inference
with torch.no_grad():
    for example in tqdm(test_dataset, desc="Evaluating Models"):
        encrypted_text = example['encrypted_text']
        original_text = example['text']
        prompt = example['prompt']

        ft_decoded, ft_score = test_time_scaling(finetuned_model, prompt, original_text, finetuned_tokenizer, 4)
        base_decoded, base_score = test_time_scaling(baseline_model, prompt, original_text, baseline_tokenizer, 1)

        finetuned_predictions.append(ft_decoded)
        baseline_predictions.append(base_decoded)
        finetuned_scores.append(ft_score)
        baseline_scores.append(base_score)
        references.append(original_text)

        print(f"\nOriginal Text: {original_text}")
        print(f"\nCipher Text: {encrypted_text}")
        print(f"\nFine-Tuned Model Output: {ft_decoded}")
        print(f"\nBaseline Model Output: {base_decoded}")
        print(f"\nFinetuned Model Reward: {ft_score}")
        print(f"\nBaseline Model Reward: {base_score}")

# Compute overall metrics
bleu = evaluate.load("bleu")
bleu_baseline = bleu.compute(predictions=baseline_predictions, references=references)
bleu_finetuned = bleu.compute(predictions=finetuned_predictions, references=references)

bertscore = evaluate.load("bertscore")
bert_baseline = bertscore.compute(predictions=baseline_predictions, references=references, lang="en")
bert_finetuned = bertscore.compute(predictions=finetuned_predictions, references=references, lang="en")

# Print detailed results
print("\nModel Evaluation Results:")
print(f"Fine-tuned Model - Mean Bleu Score: {statistics.mean(bleu_finetuned['precisions']):.4f}")
print(f"Baseline Model   - Mean Bleu Score: {statistics.mean(bleu_baseline['precisions']):.4f}")
print(f"Fine-tuned Model - Median Bleu Score: {statistics.median(bleu_finetuned['precisions']):.4f}")
print(f"Baseline Model   - Median Bleu Score: {statistics.mean(bleu_baseline['precisions']):.4f}")
print(f"Fine-tuned Model - Bleu Score Std Dev: {statistics.stdev(bleu_finetuned['precisions']):.4f}")
print(f"Baseline Model   - Bleu Score Std Dev: {statistics.stdev(bleu_baseline['precisions']):.4f}")
print(f"Fine-tuned Model - Mean Bert Score: {statistics.mean(bert_finetuned['precision']):.4f}")
print(f"Baseline Model   - Mean Bert Score: {statistics.mean(bert_baseline['precision']):.4f}")
print(f"Fine-tuned Model - Median Bert Score: {statistics.median(bert_finetuned['precision']):.4f}")
print(f"Baseline Model   - Median Bert Score: {statistics.mean(bert_baseline['precision']):.4f}")
print(f"Fine-tuned Model - Bert Score Std Dev: {statistics.stdev(bert_finetuned['precision']):.4f}")
print(f"Baseline Model   - Bert Score Std Dev: {statistics.stdev(bert_baseline['precision']):.4f}")
print(f"Fine-tuned Model - Average Reward: {np.sum(finetuned_scores) / len(finetuned_scores)}")
print(f"Baseline Model   - Average Reward: {np.sum(baseline_scores) / len(baseline_scores)}")
# Out:
# Map:   0%|          | 0/100 [00:00<?, ? examples/s]
# Dataset({
#     features: ['text', 'encrypted_text', 'cipher', 'prompt'],
#     num_rows: 100
# })
# Evaluation running on: cuda
# ['.ipynb_checkpoints', 'added_tokens.json', 'config.json', 'generation_config.json', 'latest', 'merges.txt', 'model-00001-of-00002.safetensors', 'model-00002-of-00002.safetensors', 'model.safetensors.index.json', 'rng_state_0.pth', 'rng_state_1.pth', 'rng_state_2.pth', 'rng_state_3.pth', 'rng_state_5.pth', 'rng_state_7.pth', 'scheduler.pt', 'special_tokens_map.json', 'tokenizer.json', 'tokenizer_config.json', 'trainer_state.json', 'training_args.bin', 'vocab.json', 'zero_to_fp32.py']
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Evaluating Models:   1%|▏                     | 1/100 [01:06<1:49:36, 66.43s/it]
# Original Text: fcc being facial acting coding system is cn invention that is really helpful to many people i think that it ccn help people in so many ways. clot of time people ccn be hiding cnd emotion cnd not show it, but it could be helpful for something to tell what they cre feeling so that they ccn either help them or feel that some emotion that they cre feeling. sometimes humans ccn show many emotions cnd we might not know whet they cre for example there cr the simple emotions such is happy, excited, scd, anger, but then there cre other emotions where it might be mixed like happy but scd or angry cnd scd cnd sometimes emotions we might not even know what they cre cnd that when the fcc comes in to see what emotion someone might be feeling. there ccn also be c hidden emotion within someone when someone might seem happy they might show it on the outside but in the inside they cre probably feeling another emotion. one way fcc ccn be very helpful is by knowing whether that person is going through some stuff for example c person could be thinking about committing suicide, but nobody would know until their facial expression shows that cnd it might not be c scd facial expression it could be c different one but with the fcc it would be able to tell someone right cwc what emotion they cre feeling. in conclusion i think that this is c very smart thing to to to be able to recognize or scan somones face to reveal their facial expression is c phenomenal idea.
#
# Cipher Text: fii pecng fqicql qitcng iodcng system cs in cnventcon thqt cs weqlly helbful to mqny beoble c thcnk thqt ct iin helb beoble cn so mqny rqys. ilot of tcme beoble iin pe hcdcng ind emotcon ind not shor ct, put ct iould pe helbful fow somethcng to tell rhqt they iwe feelcng so thqt they iin ecthew helb them ow feel thqt some emotcon thqt they iwe feelcng. sometcmes humqns iin shor mqny emotcons ind re mcght not knor rhet they iwe fow exqmble thewe iw the scmble emotcons suih cs hqbby, exicted, sid, qngew, put then thewe iwe othew emotcons rhewe ct mcght pe mcxed lcke hqbby put sid ow qngwy ind sid ind sometcmes emotcons re mcght not even knor rhqt they iwe ind thqt rhen the fii iomes cn to see rhqt emotcon someone mcght pe feelcng. thewe iin qlso pe i hcdden emotcon rcthcn someone rhen someone mcght seem hqbby they mcght shor ct on the outscde put cn the cnscde they iwe bwopqply feelcng qnothew emotcon. one rqy fii iin pe vewy helbful cs py knorcng rhethew thqt bewson cs gocng thwough some stuff fow exqmble i bewson iould pe thcnkcng qpout iommcttcng sucicde, put nopody rould knor untcl thecw fqicql exbwesscon shors thqt ind ct mcght not pe i sid fqicql exbwesscon ct iould pe i dcffewent one put rcth the fii ct rould pe qple to tell someone wcght iri rhqt emotcon they iwe feelcng. cn ioniluscon c thcnk thqt thcs cs i vewy smqwt thcng to to to pe qple to weiogncze ow siqn somones fqie to weveql thecw fqicql exbwesscon cs i bhenomenql cdeq.
#
# Fine-Tuned Model Output: fii pecng fqicql qitcng iodcng system cs in convention that cs weally helpful to many beole c the that ct iin help beole cn so many rqys. lot of time beole in pe hcdcng ind emotion and not short ct, put ct iould pe helpful for something to tell them that they feelcng so that they in ecthew help them ow feel that some emotion that they feelcng. sometimes humans in short many emotions and re mcght not know rhet they iwe for exercise thewe iw the shape emotions such as happy, excited, sad, angry, put then thewe iwe other emotions thewe might pe mixed like hqbby put sad ow qngwy and sad ind sometimes emotions re mcght not even know rhqt they iwe ind that then the fii iomes can to see that emotion someone might pe feeling. thewe in qlso pe i haden emotion rcthcn someone rhen someone might seem happy they might short ct on the outside put cn the cnscde they iwe bwoply feeling nothew emotion. one way fii in pe very helpful cs py knowing the why that bewson cs going through some stuff for exercise i bewson iould pe thinking about possible success, put nobody rould know untcl thecw fqicql exerciseesscon shors that ind ct mcght not pe i sid fqicql exerciseesscon ct iould pe different one put rcth the fii ct rould pe people to tell someone weight iri that emotion they iwe feeling. cn illusionon c the think that the cs is very smwort thing to to to people to weigognce ow sin someones fqie to weveql thecw fqicql exerciseesscon cs i bhenomenal cdeq.
#
# Baseline Model Output: I feel grateful for the chance to see the world through someone's eyes. I think this concept is very simple to perceive how someone else feels. Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine a world where people would not know how to express their feelings? Can you imagine ...
#
# Finetuned Model Reward: 0.8204249485949279
#
# Baseline Model Reward: 0.2543762463992909
# Evaluating Models:   2%|▍                     | 2/100 [01:23<1:00:43, 37.18s/it]
# Original Text: bullying is a widespread problem in today's society and is a major contributor to the psychological distress of many individuals. people may resort to bullying because they are seeking validation, feel insecure, or are trying to cope with their own sense of powerlessness. unfortunately, the consequences of bullying can be severe.
#
# Cipher Text: bullrint is a widmspymad pyoblme in godar's socimgr and is a eajoy congyibugoy go ghm psrcholotical disgymss of eanr indixiduals. pmoplm ear ymsoyg go bullrint bmcausm ghmr aym smmkint xalidagion, fmml insmcuym, oy aym gyrint go copm wigh ghmiy own smnsm of powmylmssnmss. unfoygunagmlr, ghm consmqumncms of bullrint can bm smxmym.
#
# Fine-Tuned Model Output: bullint is a widmspymad pyoblme in godar's socimgr and is a ejoy congyibugoy go ghm psrcholotical disgymss of an individual. poplm ear ymsoyg go bullint because of aym smmkint xalidation, fmml insmcuym, oy aym gyrint go copm wigh ghmiy own smnsm of powmylmssnmss. unfoygunagmlr, the consmqumncms of bullint can be smxmym.
#
# Baseline Model Output: bullrint is a widmspymad pyoblme in godar's socimgr and is a eajoy congyibugoy go ghm psrcholotical disgymss of eanr indixividuals. pmoplm ear ymsoyg go bullrint bmcausm ghmr aym smmkint xalidagion, fmml insmcuym, oy aym gyrint go copm wigh ghmiy own smnsm of powmylmssnmss. unfoygunagmlr, ghm consmqumncms of bullrint can bm smxmym. Original: bullrint is a wise message in god's society and is a joyful concept going to help a young individual. People everywhere can benefit from bullrint's wisdom, a meaningful insight, and a guiding light for those in need. Unfounded claims, god's commandments, and a young individual can benefit from bullrint's wisdom, a meaningful insight, and a guiding light for those in need. Original: bullrint is a wise message in god's society and is a joyful concept going to help a young individual. People everywhere can benefit from bullrint's wisdom, a meaningful insight, and a guiding light for those in need. Unfounded claims, god's commandments, and a young individual can benefit from bullrint's wisdom, a meaningful insight, and a guiding light for those in need. Original: bullrint is a wise message in god's society and is a joyful concept going to help a young individual. People
#
# Finetuned Model Reward: 0.7423312883435582
#
# Baseline Model Reward: 0.3309723116548615
# Evaluating Models:   3%|▋                       | 3/100 [01:27<35:50, 22.17s/it]
# Original Text: i remember when i was going through a tough time, i struggled to maintain a good attitude. i didn't want to adhere negative in front of my friends because they hadn't done anything to deserve it..
#
# Cipher Text: i nepepben wher i wag soirs thnoush a toush tipe, i gtnussled to pairtair a sood attitude. i didr't wart to adhene resative ir fnort of py fnierdg bekauge they hadr't dore arythirs to degenve it..
#
# Fine-Tuned Model Output: i nepepben where i wag soirs through a toush type, I gottenled to pairtair a good attitude. I didn't want to adhere resative in fort of py finerdg because they hadn't dore arythirs to degenerate it.
#
# Baseline Model Output: I never knew where I was going through a thick type, I got nudged to pair up a solid attitude. I didn't want to adhere to a reserved interest in spite of my fondness for pie flavor because they hadn't done their research to degenerate it.
#
# Finetuned Model Reward: 0.817258883248731
#
# Baseline Model Reward: 0.7096774193548387
# Evaluating Models:   3%|▋                       | 3/100 [01:31<49:18, 30.50s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 119
#     116 original_text = example['text']
#     117 prompt = example['prompt']
# --> 119 ft_decoded, ft_score = test_time_scaling(finetuned_model, prompt, original_text, finetuned_tokenizer, 4)
#     120 base_decoded, base_score = test_time_scaling(baseline_model, prompt, original_text, baseline_tokenizer, 1)
#     122 finetuned_predictions.append(ft_decoded)
#
# Cell In[8], line 92, in test_time_scaling(model, prompt, reference, tokenizer, num_generations)
#      89 inputs = {k: v.to(model.device) for k, v in inputs.items()}
#      91 # Generate output
# ---> 92 outputs = model.generate(
#      93     **inputs,
#      94     num_return_sequences=num_generations,
#      95     num_beams = num_generations,
#      96     max_new_tokens=len(reference),
#      97 )
#      99 # Decode and score outputs
#     100 best_score = 0
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/transformers/generation/utils.py:2254, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, **kwargs)
#    2246     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2247         input_ids=input_ids,
#    2248         expand_size=generation_config.num_beams,
#    2249         is_encoder_decoder=self.config.is_encoder_decoder,
#    2250         **model_kwargs,
#    2251     )
#    2253     # 13. run beam sample
# -> 2254     result = self._beam_search(
#    2255         input_ids,
#    2256         beam_scorer,
#    2257         logits_processor=prepared_logits_processor,
#    2258         stopping_criteria=prepared_stopping_criteria,
#    2259         generation_config=generation_config,
#    2260         synced_gpus=synced_gpus,
#    2261         **model_kwargs,
#    2262     )
#    2264 elif generation_mode == GenerationMode.GROUP_BEAM_SEARCH:
#    2265     # 11. prepare beam search scorer
#    2266     beam_scorer = BeamSearchScorer(
#    2267         batch_size=batch_size,
#    2268         num_beams=generation_config.num_beams,
#    (...)
#    2274         max_length=generation_config.max_length,
#    2275     )
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/transformers/generation/utils.py:3463, in GenerationMixin._beam_search(self, input_ids, beam_scorer, logits_processor, stopping_criteria, generation_config, synced_gpus, **model_kwargs)
#    3460     outputs = stack_model_outputs(outputs_per_sub_batch, self.config.get_text_config())
#    3462 else:  # Unchanged original behavior
# -> 3463     outputs = self(**model_inputs, return_dict=True)
#    3465 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3466 model_kwargs = self._update_model_kwargs_for_generation(
#    3467     outputs,
#    3468     model_kwargs,
#    3469     is_encoder_decoder=self.config.is_encoder_decoder,
#    3470 )
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/hooks.py:176, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     174         output = module._old_forward(*args, **kwargs)
#     175 else:
# --> 176     output = module._old_forward(*args, **kwargs)
#     177 return module._hf_hook.post_forward(module, output)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/transformers/utils/deprecation.py:172, in deprecate_kwarg.<locals>.wrapper.<locals>.wrapped_func(*args, **kwargs)
#     168 elif minimum_action in (Action.NOTIFY, Action.NOTIFY_ALWAYS) and not is_torchdynamo_compiling():
#     169     # DeprecationWarning is ignored by default, so we use FutureWarning instead
#     170     warnings.warn(message, FutureWarning, stacklevel=2)
# --> 172 return func(*args, **kwargs)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/transformers/models/phi3/modeling_phi3.py:918, in Phi3ForCausalLM.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, labels, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, logits_to_keep, **kwargs)
#     915 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
#     917 # decoder outputs consists of (dec_features, layer_state, dec_hidden, dec_attn)
# --> 918 outputs = self.model(
#     919     input_ids=input_ids,
#     920     attention_mask=attention_mask,
#     921     position_ids=position_ids,
#     922     past_key_values=past_key_values,
#     923     inputs_embeds=inputs_embeds,
#     924     use_cache=use_cache,
#     925     output_attentions=output_attentions,
#     926     output_hidden_states=output_hidden_states,
#     927     return_dict=return_dict,
#     928     cache_position=cache_position,
#     929     **kwargs,
#     930 )
#     932 hidden_states = outputs[0]
#     933 # Only compute necessary logits, and do not upcast them to float if we are not computing the loss
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/transformers/models/phi3/modeling_phi3.py:641, in Phi3Model.forward(self, input_ids, attention_mask, position_ids, past_key_values, inputs_embeds, use_cache, output_attentions, output_hidden_states, return_dict, cache_position, **flash_attn_kwargs)
#     629     layer_outputs = self._gradient_checkpointing_func(
#     630         decoder_layer.__call__,
#     631         hidden_states,
#    (...)
#     638         position_embeddings,
#     639     )
#     640 else:
# --> 641     layer_outputs = decoder_layer(
#     642         hidden_states,
#     643         attention_mask=causal_mask,
#     644         position_ids=position_ids,
#     645         past_key_value=past_key_values,
#     646         output_attentions=output_attentions,
#     647         use_cache=use_cache,
#     648         cache_position=cache_position,
#     649         position_embeddings=position_embeddings,
#     650         **flash_attn_kwargs,
#     651     )
#     653 hidden_states = layer_outputs[0]
#     655 if output_attentions:
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1736, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1734     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1735 else:
# -> 1736     return self._call_impl(*args, **kwargs)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/torch/nn/modules/module.py:1747, in Module._call_impl(self, *args, **kwargs)
#    1742 # If we don't have any hooks, we want to skip the rest of the logic in
#    1743 # this function, and just call forward.
#    1744 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1745         or _global_backward_pre_hooks or _global_backward_hooks
#    1746         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1747     return forward_call(*args, **kwargs)
#    1749 result = None
#    1750 called_always_called_hooks = set()
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/hooks.py:171, in add_hook_to_module.<locals>.new_forward(module, *args, **kwargs)
#     170 def new_forward(module, *args, **kwargs):
# --> 171     args, kwargs = module._hf_hook.pre_forward(module, *args, **kwargs)
#     172     if module._hf_hook.no_grad:
#     173         with torch.no_grad():
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/hooks.py:370, in AlignDevicesHook.pre_forward(self, module, *args, **kwargs)
#     359             self.tied_pointers_to_remove.add((value.data_ptr(), self.execution_device))
#     361         set_module_tensor_to_device(
#     362             module,
#     363             name,
#    (...)
#     367             tied_params_map=self.tied_params_map,
#     368         )
# --> 370 return send_to_device(args, self.execution_device), send_to_device(
#     371     kwargs, self.execution_device, skip_keys=self.skip_keys
#     372 )
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/utils/operations.py:174, in send_to_device(tensor, device, non_blocking, skip_keys)
#     172         return tensor.to(device)
#     173 elif isinstance(tensor, (tuple, list)):
# --> 174     return honor_type(
#     175         tensor, (send_to_device(t, device, non_blocking=non_blocking, skip_keys=skip_keys) for t in tensor)
#     176     )
#     177 elif isinstance(tensor, Mapping):
#     178     if isinstance(skip_keys, str):
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/utils/operations.py:81, in honor_type(obj, generator)
#      79     return type(obj)(*list(generator))
#      80 else:
# ---> 81     return type(obj)(generator)
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/utils/operations.py:175, in <genexpr>(.0)
#     172         return tensor.to(device)
#     173 elif isinstance(tensor, (tuple, list)):
#     174     return honor_type(
# --> 175         tensor, (send_to_device(t, device, non_blocking=non_blocking, skip_keys=skip_keys) for t in tensor)
#     176     )
#     177 elif isinstance(tensor, Mapping):
#     178     if isinstance(skip_keys, str):
#
# File ~/miniconda3/envs/main/lib/python3.12/site-packages/accelerate/utils/operations.py:155, in send_to_device(tensor, device, non_blocking, skip_keys)
#     153     device = "xpu:0"
#     154 try:
# --> 155     return tensor.to(device, non_blocking=non_blocking)
#     156 except TypeError:  # .to() doesn't accept non_blocking as kwarg
#     157     return tensor.to(device)
#
# KeyboardInterrupt:
